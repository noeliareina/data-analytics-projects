# %% [markdown]
# # 🛜 Set-up para la conexión entre mysql y python 🛜

# %%
import json
import pandas as pd
import mysql.connector
from mysql.connector import errorcode

# %% [markdown]
# 1. Nos conectamos a la base de datos (script de creación en _schema_bbdd.sql_)

# %%
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
host='127.0.0.1',
database='musicstream', 
auth_plugin ='mysql_native_password')

# %% [markdown]
# 2. Creamos el cursor

# %%
mycursor = cnx.cursor()

# %% [markdown]
# # 🏗️ Añadiendo datos desde los ficheros .csv 🏗️

# %% [markdown]
# ### Añadimos los datos a la tabla zonas

# %%
query = "INSERT INTO regions(region_name) VALUES(%s)"
val = [[('mediterranean')], [('north')], [('centre')], [('east')]]
mycursor.executemany(query, val)
cnx.commit()

# %% [markdown]
# ### Añadimos los datos a la tabla países

# %% [markdown]
# 1. Definimos los diccionarios con los paises para cada zona

# %%
paises_mediterraneos = {
    "ES": "España",
    "FR": "Francia",
    "MC": "Mónaco",
    "IT": "Italia",
    "SI": "Eslovenia",
    "HR": "Croacia",
    "BA": "Bosnia y Herzegovina",
    "ME": "Montenegro",
    "AL": "Albania",
    "GR": "Grecia",
    "MT": "Malta",
    "CY": "Chipre"}
paises_este_europa = {
    "BY": "Bielorrusia",
    "BG": "Bulgaria",
    "CZ": "Chequia",
    "SK": "Eslovaquia",
    "HU": "Hungría",
    "MD": "Moldavia",
    "PL": "Polonia",
    "RO": "Rumanía",
    "UA": "Ucrania"}
paises_norte_europa = {
    "DK": "Dinamarca",
    "EE": "Estonia",
    "FI": "Finlandia",
    "IS": "Islandia",
    "IE": "Irlanda",
    "LT": "Lituania",
    "LV": "Letonia",
    "NO": "Noruega",
    "SE": "Suecia",
    "GB": "Reino Unido"}
paises_europa_central = {
    "AT": "Austria",
    "DE": "Alemania",
    "CH": "Suiza",
    "LI": "Liechtenstein",
    "BE": "Bélgica",
    "LU": "Luxemburgo",
    "NL": "Países Bajos"}

# %% [markdown]
# 2. Definimos la función `añadir_pais`

# %%
def add_country(dictionary, region_id):
    ''' Añade datos a la tabla de paises.

        Args: 
            diccionario (dict): Un diccionario de los definidos para cada zona donde se recogen los países y sus códigos.
            id_zona (int): Número asignado a cada zona de europa en la tabla zonas. 

    '''
    for id, country in dictionary.items():
        query = "INSERT INTO countries(country_id, country_name, region_id) VALUES(%s, %s, %s)"
        val = [(id, country, region_id)] 
        mycursor.executemany(query, val)
        cnx.commit()

# %% [markdown]
# Los id_zona quedan entonces como:
# - 1 mediterraneo
# - 2 norte
# - 3 centro
# - 4 este

# %% [markdown]
# 3. Llamamos a la función en bucle para añadir los países de cada zona de una sola vez.

# %%
# Definimos estas dos listas, que nos van a servir para poder llamar en bucle a la función. Es MUY IMPORTANTE el orden, debe coincidir el nombre del diccionario con el id_zona asignado a cada zona.
lista_diccionarios = [paises_mediterraneos, paises_norte_europa, paises_europa_central, paises_este_europa]
lista_zonas = [i for i in range(1,5)]

# %%
for i in range(len(lista_diccionarios)):
    add_country(lista_diccionarios[i], lista_zonas[i])

# %% [markdown]
# ### Añadimos los datos a la tabla años

# %%
query_años = "INSERT INTO decades(year_range) VALUES(%s)"
val_años = [[('2000-2004')], [('2005-2009')], [('2010-2014')], [('2015-2019')], [('2020-2024')]]
mycursor.executemany(query_años, val_años)
cnx.commit()

# %% [markdown]
# ### Añadimos los datos a la tabla artistas

# %% [markdown]
# 1. Definimos la función `convertir_csv`, que convierte cada uno de los csv que hemos creado en un DataFrame.

# %%
def convertir_csv(zona, años):
    ''' Convierte el csv de cada zona y rango de años en un DataFrame.
    
        Args:
            zona (str): Nombre de la zona.
            años (str): Rango de años en la forma añoinicio_añofin. 
    '''
    df = pd.read_csv(f'csv_files/{zona}_{años}.csv',index_col = 0)
    return df

# %% [markdown]
# 2. Llamamos a la función una vez por cada csv que debemos convertir.

# %%
# Definimos estas dos listas, que nos van a servir para poder llamar a la función.
lista_nombre_zona = ["east", "centre", "mediterranean", "north"]
lista_años = ["2000_2004", "2005_2009", "2010_2014", "2015_2019", "2020_2024"]

# %%
# Países del este
df_east_2000_2004 = convertir_csv(lista_nombre_zona[0], lista_años[0])
df_east_2005_2009 = convertir_csv(lista_nombre_zona[0], lista_años[1])
df_east_2010_2014 = convertir_csv(lista_nombre_zona[0], lista_años[2])
df_east_2015_2019 = convertir_csv(lista_nombre_zona[0], lista_años[3])
df_east_2020_2024 = convertir_csv(lista_nombre_zona[0], lista_años[4])

# %%
# Países del centro
df_centre_2000_2004 = convertir_csv(lista_nombre_zona[1], lista_años[0])
df_centre_2005_2009 = convertir_csv(lista_nombre_zona[1], lista_años[1])
df_centre_2010_2014 = convertir_csv(lista_nombre_zona[1], lista_años[2])
df_centre_2015_2019 = convertir_csv(lista_nombre_zona[1], lista_años[3])
df_centre_2020_2024 = convertir_csv(lista_nombre_zona[1], lista_años[4])

# %%
# Países mediterráneos
df_medit_2000_2004 = convertir_csv(lista_nombre_zona[2], lista_años[0])
df_medit_2005_2009 = convertir_csv(lista_nombre_zona[2], lista_años[1])
df_medit_2010_2014 = convertir_csv(lista_nombre_zona[2], lista_años[2])
df_medit_2015_2019 = convertir_csv(lista_nombre_zona[2], lista_años[3])
df_medit_2020_2024 = convertir_csv(lista_nombre_zona[2], lista_años[4])

# %%
# Países del norte
df_north_2000_2004 = convertir_csv(lista_nombre_zona[3], lista_años[0])
df_north_2005_2009 = convertir_csv(lista_nombre_zona[3], lista_años[1])
df_north_2010_2014 = convertir_csv(lista_nombre_zona[3], lista_años[2])
df_north_2015_2019 = convertir_csv(lista_nombre_zona[3], lista_años[3])
df_north_2020_2024 = convertir_csv(lista_nombre_zona[3], lista_años[4])

# %%
csv_df_list = [df_east_2000_2004, df_east_2005_2009, df_east_2010_2014, df_east_2015_2019, df_east_2020_2024, df_centre_2000_2004, df_centre_2005_2009, df_centre_2010_2014,
                df_centre_2015_2019, df_centre_2020_2024, df_medit_2000_2004, df_medit_2005_2009, df_medit_2010_2014, df_medit_2015_2019, df_medit_2020_2024,df_north_2000_2004,
                df_north_2005_2009, df_north_2010_2014, df_north_2015_2019, df_north_2020_2024]

# %%
df_list_in_order = []
for l in lista_df_csv:
    var = l.sort_values(['popularity'], axis=0, ascending=False, ignore_index=True)[0:50]
    df_list_in_order.append(var)

# %% [markdown]
# 3. Creamos una lista de artistas vacía y luego un DataFrame con todos los artistas por zona.

# %%
artistas = []
df_mediterranean = pd.concat(
    [df_medit_2000_2004['artista'], df_medit_2005_2009['artista'], df_medit_2010_2014['artista'], df_medit_2015_2019['artista'], df_medit_2020_2024['artista']],
    axis=1,
    keys=["00-04", "05-09", "10-14", "15-19", "20-24"])
df_east = pd.concat(
    [df_east_2000_2004['artista'], df_east_2005_2009['artista'], df_east_2010_2014['artista'], df_east_2015_2019['artista'], df_east_2020_2024['artista']],
    axis=1,
    keys=["00-04", "05-09", "10-14", "15-19", "20-24"])
df_centre = pd.concat(
    [df_centre_2000_2004['artista'], df_centre_2005_2009['artista'], df_centre_2010_2014['artista'], df_centre_2015_2019['artista'], df_centre_2020_2024['artista']],
    axis=1,
    keys=["00-04", "05-09", "10-14", "15-19", "20-24"])
df_north = pd.concat(
    [df_north_2000_2004['artista'], df_north_2005_2009['artista'], df_north_2010_2014['artista'], df_north_2015_2019['artista'], df_north_2020_2024['artista']],
    axis=1,
    keys=["00-04", "05-09", "10-14", "15-19", "20-24"])

# %%
# Esta lista es para poder meter los datos de los df en bucle.
lista_df = [df_mediterranean, df_east, df_centre, df_north]

# %% [markdown]
# 4. Con el siguiente bucle, convertimos cada artista en una lista y lo añadimos a la lista artistas.

# %%
for df in lista_df:
    for i in df.itertuples(name=None, index=False):
        for n in range(4):
            if ([i[n]]) not in artistas:
                artistas.append(i[n]) #avoiding repetitions

# %%
len(artistas)
# Out:
# 981

# %% [markdown]
# 5. Ejecutamos la inserción

# %%
artists_query = "INSERT INTO artists(artist_name) VALUES(%s)"
for artist in artistas:
    try:
     mycursor.execute(artists_query, artist)
     cnx.commit()
    except:
      continue
cnx.close()

# %% [markdown]
# ### Añadimos los datos a la tabla canciones

# %% [markdown]
# Recordemos los decade_id para cada conjunto de 5 años:
# - 1 = 2000-2004
# - 2 = 2005-2009
# - 3 = 2010-2014
# - 4 = 2015-2019
# - 5 = 2020-2024

# %% [markdown]
# Volvemos a abrir la conexión y a definir el cursor

# %%
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab', host='127.0.0.1',
                                    database='musicstream', 
                                    auth_plugin ='mysql_native_password')
mycursor = cnx.cursor()

# %% [markdown]
# Hay algunos datos que son `NaN`, y MySQL no los reconoce, por lo que hay que convertirlos a None.
#
# Para ello, creamos la función `eliminar_nan`

# %%
def remove_nan (df):
    df_clean = df.replace({float('NaN'): None})
    return df_clean

# %% [markdown]
# Limpiamos los df y lo metemos en la lista `lista_df_limpios`

# %%
df_clean_list = []

for data in df_list_in_order:
    df_clean = remove_nan(data)
    df_clean_list.append(df_clean)

# %% [markdown]
# Definimos una función para insertar las canciones

# %%
def insert_songs (df):
    querys_list = []
    for i in range(len(df)):
        tupla_insercion = (str(df['nombre'][i]), str(df['genero'][i]), int(df['popularity'][i]))
        querys_list.append(tupla_insercion)
    return querys_list

# %% [markdown]
# Creamos la lista de tuplas para insertar, descartando aquellas canciones que coinciden en todos los campos.

# %%
tuples_list = []

for df in df_clean_list:    
    tuples = insert_songs(df)
    for t in tuples:
        if t not in tuples_list:
            tuples_list.append(t)

# %% [markdown]
# Definimos la query canciones:

# %%
query_songs = "INSERT INTO songs(song_title, genre, popularity) VALUES(%s, %s, %s)"

# %%
mycursor.executemany(query_songs, tuples_list)
cnx.commit()

# %%
cnx.close()

# %% [markdown]
# ### Añadimos los datos a las tablas intermedias

# %% [markdown]
# Primero, pais en cancion:

# %%
contador = 0
country_song_queries = []
for t in tuples_list:
    contador += 1
    for df in df_clean_list:
        for i in range(len(df)):
            if df['nombre'][i] in t:
                song_country_tuple = (df['pais'][i], contador)
                country_song_queries.append(song_country_tuple)

# %%
country_in_song_query = "INSERT INTO country_in_song(country_id, song_id) VALUES(%s, %s)"

# %%
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab', host='127.0.0.1',
                                    database='musicstream', 
                                    auth_plugin ='mysql_native_password')
mycursor = cnx.cursor()

# %%
for q in country_song_queries:
    try:
        mycursor.execute(country_in_song_query, q)
        cnx.commit()
    except:
        print(f"La entrada {q} está repetida")
# Out:
# La entrada ('BY', 55) está repetida
# La entrada ('BY', 55) está repetida
# La entrada ('RO', 55) está repetida
# La entrada ('BY', 58) está repetida
# La entrada ('BY', 58) está repetida
# La entrada ('RO', 58) está repetida

# %%
cnx.close()

# %% [markdown]
# Ahora, lo mismo con artista en cancion:

# %%
song_artist_query = []

for t in tuples_list:
    # Ajusta según tu estructura real:
    song_title = t[0]
    artist_name = t[1]
    
    q_id_artist = "SELECT artist_id FROM artists WHERE artist_name = %s;"
    q_id_song = "SELECT song_id FROM songs WHERE song_title = %s;"
    
    # Buscar artista
    mycursor.execute(q_id_artist, (artist_name,))
    artist_result = mycursor.fetchone()
    mycursor.fetchall()  # limpiar resultados previos

    # Buscar canción
    mycursor.execute(q_id_song, (song_title,))
    song_result = mycursor.fetchone()
    mycursor.fetchall()

    if artist_result and song_result:
        artist_id = artist_result[0]
        song_id = song_result[0]
        song_artist_query.append((artist_id, song_id))
    else:
        print(f"⚠️ No match found for: {song_title} - {artist_name}")

# Insertar relaciones válidas
if song_artist_query:
    insert_query = "INSERT INTO artist_in_song (artist_id, song_id) VALUES (%s, %s)"
    mycursor.executemany(insert_query, song_artist_query)
    cnx.commit()
    print(f"✅ Inserted {len(song_artist_query)} artist-song relations successfully.")
else:
    print("❌ No valid artist-song pairs found.")
# Out:
# ⚠️ No match found for: Yellow - rock
# ⚠️ No match found for: Numb - rock
# ⚠️ No match found for: Without Me - rap
# ⚠️ No match found for: Mr. Brightside - rock
# ⚠️ No match found for: In the End - rock
# ⚠️ No match found for: The Real Slim Shady - rap
# ⚠️ No match found for: Mockingbird - rap
# ⚠️ No match found for: Unwritten - pop
# ⚠️ No match found for: Headlock - electronic
# ⚠️ No match found for: Feel Good Inc. - alternative
# ⚠️ No match found for: Breakin' Dishes - rnb
# ⚠️ No match found for: 505 - indie rock
# ⚠️ No match found for: Flashing Lights - None
# ⚠️ No match found for: Hips Don't Lie (feat. Wyclef Jean) - None
# ⚠️ No match found for: Promiscuous - None
# ⚠️ No match found for: I Wanna Be Yours - indie rock
# ⚠️ No match found for: Sweater Weather - indie
# ⚠️ No match found for: Locked out of Heaven - pop
# ⚠️ No match found for: No. 1 Party Anthem - indie rock
# ⚠️ No match found for: A Sky Full of Stars - pop
# ⚠️ No match found for: Give Me Everything (feat. Nayer) - None
# ⚠️ No match found for: Counting Stars - pop rock
# ⚠️ No match found for: Do I Wanna Know? - indie rock
# ⚠️ No match found for: Wake Me Up - electronic
# ⚠️ No match found for: Another Love - indie
# ⚠️ No match found for: Lovers Rock - indie pop
# ⚠️ No match found for: All The Stars (with SZA) - None
# ⚠️ No match found for: See You Again (feat. Kali Uchis) - None
# ⚠️ No match found for: HUMBLE. - rap
# ⚠️ No match found for: The Night We Met - indie
# ⚠️ No match found for: Starboy - None
# ⚠️ No match found for: Swim - seen live
# ⚠️ No match found for: Something Just Like This - None
# ⚠️ No match found for: lovely (with Khalid) - None
# ⚠️ No match found for: Softcore - alternative
# ⚠️ No match found for: The Hills - rnb
# ⚠️ No match found for: Believer - rock
# ⚠️ No match found for: goosebumps - MySpotigramBot
# ⚠️ No match found for: There's Nothing Holdin' Me Back - pop
# ⚠️ No match found for: Ransom - 2010s
# ⚠️ No match found for: Die With A Smile - None
# ⚠️ No match found for: BIRDS OF A FEATHER - alt-pop
# ⚠️ No match found for: Not Like Us - MySpotigramBot
# ⚠️ No match found for: That’s So True - love at first listen
# ⚠️ No match found for: APT. - None
# ⚠️ No match found for: Clean Baby Sleep White Noise (Loopable) - None
# ⚠️ No match found for: tv off (feat. lefty gunplay) - None
# ⚠️ No match found for: WILDFLOWER - edu e marco
# ⚠️ No match found for: Sailor Song - indie folk
# ⚠️ No match found for: Good Luck, Babe! - synthpop
# ⚠️ No match found for: Timeless (feat. Playboi Carti) - None
# ⚠️ No match found for: Who - homosexual
# ⚠️ No match found for: Messy - indie rock
# ⚠️ No match found for: The Days - NOTION Remix - None
# ⚠️ No match found for: Who - homosexual
# ⚠️ No match found for: Sparks - rock
# ⚠️ No match found for: When I Was Your Man - pop
# ⚠️ No match found for: Night Changes - pop
# ⚠️ No match found for: HUMBLE. - None
# ⚠️ No match found for: Cruel Summer - None
# ⚠️ No match found for: The Night We Met - None
# ⚠️ No match found for: That's What I Like - None
# ⚠️ No match found for: Swim - None
# ⚠️ No match found for: Perfect - None
# ⚠️ No match found for: The Night We Met - indie
# ⚠️ No match found for: Cruel Summer - electropop
# ⚠️ No match found for: That's What I Like - funk
# ✅ Inserted 4 artist-song relations successfully.

# %%
song_artist_query
# Out:
# [(20, 4), (20, 12), (109, 16), (20, 60)]

# %%
info_artists = f"SELECT artist_id FROM artists WHERE artist_name = '{df_clean_list[0]['artista'][0]}';"

# %%
info_songs = f"SELECT artist_id  FROM artists WHERE song_title = '{df_clean_list[0]['nombre'][0]}' AND id_lustro;"

# %% [markdown]
# Por último ,metemos lustro en cancion, es decir, relacionamos "decade_of_song" con "songs"
